# %%
pip install sidrapy
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached sidrapy-0.1.4-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.0.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached charset_normalizer-3.3.2-cp312-cp312-win_amd64.whl.metadata (34 kB)
# ...
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# ...
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# ...
#   Using cached certifi-2024.7.4-py3-none-any.whl.metadata (2.2 kB)
# ...
# Using cached sidrapy-0.1.4-py3-none-any.whl (6.9 kB)
# Using cached pandas-2.2.2-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# ...

# %%
import sidrapy
import pandas as pd

# %%
pop=sidrapy.get_table(
table_code='4709',
territorial_level='6',
ibge_territorial_code='all',
period='all',
variable='all',
)

print(pop.shape)
pop.head()
# Out:
# (16711, 11)
#                            NC                 NN                          MC  \
# 0  Nível Territorial (Código)  Nível Territorial  Unidade de Medida (Código)
# 1                           6          Município                          45
# 2                           6          Município                          45
# 3                           6          Município                           2
# 4                           6          Município                          45
#
#                   MN      V                 D1C                         D1N  \
# 0  Unidade de Medida  Valor  Município (Código)                   Município
# 1            Pessoas  21494             1100015  Alta Floresta D'Oeste - RO
# 2            Pessoas  -2898             1100015  Alta Floresta D'Oeste - RO
# 3                  %  -1.05             1100015  Alta Floresta D'Oeste - RO
# 4            Pessoas  96833             1100023              Ariquemes - RO
#
# ...

# %%
pop= pop.apply(lambda x: x.str.normalize('NFKD').str.encode('ascili', errors='ignore').str.decode('utf-8') if x.dtype == 'object' else x)

pop =pop.iloc[1:]

pop.head()
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pop= pop.apply(lambda x: x.str.normalize('NFKD').str.encode('ascili', errors='ignore').str.decode('utf-8') if x.dtype == 'object' else x)
#       3 # djdjddedef
#       5 pop =pop.iloc[1:]
#
# File c:\Users\ALUNO.DESKTOP-1FIO5DS\Desktop\Andre_uc5\.venv\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\ALUNO.DESKTOP-1FIO5DS\Desktop\Andre_uc5\.venv\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
# ...
